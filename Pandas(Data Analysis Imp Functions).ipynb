# %% [markdown]
# # Pandas
# It is an open-source library in Python that is made mainly for working with relational or labeled data both easily and intuitively. It provides various data structures and operations for manipulating numerical data and time series. This library is built on top of the NumPy library of Python. Pandas is fast and it has high performance & productivity for users.
#
# What can you do using Pandas?\
# -Data set cleaning, merging, and joining.\
# -Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data.\
# -Columns can be inserted and deleted from DataFrame and higher dimensional objects.\
# -Powerful group by functionality for performing split-apply-combine operations on data sets.\
# -Data Visulaization

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("C:\\PujaFiles\Excel data for practice\\test.csv") 
df.head(3) #top 3 rows'
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   34      Travel_Rarely        790                     NaN
# 1   35      Travel_Rarely        660                     NaN
# 2   24  Travel_Frequently        381  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                24          4        Medical            NaN            1489
# 1                 7          1  Life Sciences            1.0            1492
# 2                 9          3        Medical            1.0            1494
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        1  ...                        3             80
# 1                        4  ...                        1             80
# 2                        2  ...                        3             80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %%
df.columns #to get column name
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes #to get datatype of all variable/columns
# Out:
# Age                           int64
# BusinessTravel               object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount               float64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# Over18                       object
# OverTime                     object
# PercentSalaryHike             int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StandardHours                 int64
# ...

# %%
df['Department'].unique()  #unique values of depertment columns
# Out:
# array([nan, 'Research & Development', 'Sales', 'Human Resources'],
#       dtype=object)

# %%
df['Department'].nunique() #no.of / count of unique values
# Out:
# 3

# %%
df.shape  #no.of rows and  columns
# Out:
# (412, 34)

# %%
df.info() # to get info like memory usage ,columns , rows, datapypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       412 non-null    int64
#  1   BusinessTravel            412 non-null    object
#  2   DailyRate                 412 non-null    int64
#  3   Department                409 non-null    object
#  4   DistanceFromHome          412 non-null    int64
#  5   Education                 412 non-null    int64
#  6   EducationField            412 non-null    object
#  7   EmployeeCount             405 non-null    float64
#  8   EmployeeNumber            412 non-null    int64
#  9   EnvironmentSatisfaction   412 non-null    int64
#  10  Gender                    412 non-null    object
#  11  HourlyRate                412 non-null    int64
#  12  JobInvolvement            412 non-null    int64
#  13  JobLevel                  412 non-null    int64
# ...

# %%
df.describe() # to get statistical informaton .(only for numerical variable )
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  412.000000   412.000000        412.000000  412.000000          405.0
# mean    36.584951   784.364078          9.742718    3.000000            1.0
# std      8.389257   390.361319          8.258996    1.001216            0.0
# min     18.000000   104.000000          1.000000    1.000000            1.0
# 25%     31.000000   464.750000          2.000000    2.000000            1.0
# 50%     35.500000   740.500000          8.000000    3.000000            1.0
# 75%     42.000000  1147.750000         15.000000    4.000000            1.0
# max     60.000000  1495.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      412.000000               412.000000  412.000000      412.000000
# mean      1777.565534                 2.745146   66.526699        2.711165
# ...

# %%
a=df.sort_values('Age',ascending=True).reset_index()
a.head(5)
# Out:
#    index  Age     BusinessTravel  DailyRate              Department  \
# 0     95   18  Travel_Frequently        544                   Sales
# 1    253   18         Non-Travel       1431  Research & Development
# 2    120   20      Travel_Rarely       1141                   Sales
# 3    139   20      Travel_Rarely        727                   Sales
# 4     94   21      Travel_Rarely        546  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 3          2        Medical            1.0            1624
# 1                14          3        Medical            1.0            1839
# 2                 2          3        Medical            1.0            1657
# 3                 9          1  Life Sciences            1.0            1680
# 4                 5          1        Medical            1.0            1623
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  412.000000   412.000000        412.000000  412.000000          405.0
# mean    36.584951   784.364078          9.742718    3.000000            1.0
# std      8.389257   390.361319          8.258996    1.001216            0.0
# min     18.000000   104.000000          1.000000    1.000000            1.0
# 25%     31.000000   464.750000          2.000000    2.000000            1.0
# 50%     35.500000   740.500000          8.000000    3.000000            1.0
# 75%     42.000000  1147.750000         15.000000    4.000000            1.0
# max     60.000000  1495.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      412.000000               412.000000  412.000000      412.000000
# mean      1777.565534                 2.745146   66.526699        2.711165
# ...

# %%
df.describe(include ='object')
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count             412                     409            412    412
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq              297                     260            170    262
#
#                 JobRole MaritalStatus Over18 OverTime
# count               412           412    412      412
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                 94           209    412      303

# %%
df.BusinessTravel.value_counts()
# Out:
# Travel_Rarely        297
# Travel_Frequently     72
# Non-Travel            43
# Name: BusinessTravel, dtype: int64

# %%
#df.describe(include='all') # statistical summury including object variable /categorical variable

# %%
#len: lenth
len(df[df['Department']== 'Sales'])
# Out:
# 124

# %%
len(df[df['MaritalStatus']=='Single'])
# Out:
# 118

# %%
#Name of Education Field where BusinessTravel=Travel_Rarely
df[df['BusinessTravel']=='Travel_Rarely'] [['EducationField','BusinessTravel']]
# Out:
#     EducationField BusinessTravel
# 0          Medical  Travel_Rarely
# 1    Life Sciences  Travel_Rarely
# 5    Life Sciences  Travel_Rarely
# 6    Life Sciences  Travel_Rarely
# 7    Life Sciences  Travel_Rarely
# ..             ...            ...
# 404      Marketing  Travel_Rarely
# 406          Other  Travel_Rarely
# 408        Medical  Travel_Rarely
# 409  Life Sciences  Travel_Rarely
# 411        Medical  Travel_Rarely
#
# [297 rows x 2 columns]

# %%
#list of JobRole that are from Sales department and Age between 30 and 32
df[ (df['Department']=='Sales') &(df['Age'].between(30,32)) ]  [['JobRole','Department','Age']]
# Out:
#                   JobRole Department  Age
# 48        Sales Executive      Sales   30
# 51        Sales Executive      Sales   30
# 86        Sales Executive      Sales   31
# 133       Sales Executive      Sales   31
# 179       Sales Executive      Sales   32
# 183       Sales Executive      Sales   32
# 189       Sales Executive      Sales   31
# 193       Sales Executive      Sales   30
# 199       Sales Executive      Sales   31
# 216       Sales Executive      Sales   31
# 248       Sales Executive      Sales   31
# 261       Sales Executive      Sales   32
# 268       Sales Executive      Sales   32
# 280  Sales Representative      Sales   30
# 300       Sales Executive      Sales   31
# 337       Sales Executive      Sales   31
# 359  Sales Representative      Sales   31
# 370  Sales Representative      Sales   32
# 373       Sales Executive      Sales   32

# %%
df.Department.replace("Sales","SALES",inplace=True)
df.Department.head(8)
# Out:
# 0                       NaN
# 1                       NaN
# 2    Research & Development
# 3                     SALES
# 4    Research & Development
# 5                     SALES
# 6           Human Resources
# 7    Research & Development
# Name: Department, dtype: object

# %%
df.Department.replace("SALES","Sales",inplace=True)
df.Department.head(4)
# Out:
# 0                       NaN
# 1                       NaN
# 2    Research & Development
# 3                     Sales
# Name: Department, dtype: object

# %%
# Get Top 3 JobRole 
df['JobRole'].value_counts().head(3) 
#value_counts:it will count the number of records for every combination of unique values for every column(in descending order)
# Out:
# Sales Executive          94
# Research Scientist       78
# Laboratory Technician    71
# Name: JobRole, dtype: int64

# %%
#data where Age is between 15 and 20
df[ df['Age'].between(15,20)]
#or 
#df[(df['Age']>=15) & (df['Age']<=20)]
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 95    18  Travel_Frequently        544                   Sales
# 120   20      Travel_Rarely       1141                   Sales
# 139   20      Travel_Rarely        727                   Sales
# 253   18         Non-Travel       1431  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 95                  3          2        Medical            1.0
# 120                 2          3        Medical            1.0
# 139                 9          1  Life Sciences            1.0
# 253                14          3        Medical            1.0
#
#      EmployeeNumber  EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# 95             1624                        2  ...                        3
# 120            1657                        3  ...                        1
# 139            1680                        4  ...                        1
# ...

# %%
#sort order by DailyRate in descending order
df.sort_values(by='DailyRate',ascending=False).head()
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 144   38  Travel_Rarely       1495  Research & Development                 4
# 364   35  Travel_Rarely       1490  Research & Development                11
# 284   34  Travel_Rarely       1480                   Sales                 4
# 311   28  Travel_Rarely       1475                   Sales                13
# 105   37  Travel_Rarely       1470  Research & Development                10
#
#      Education EducationField  EmployeeCount  EmployeeNumber  \
# 144          2        Medical            1.0            1687
# 364          4        Medical            1.0            2003
# 284          3  Life Sciences            1.0            1882
# 311          2      Marketing            1.0            1933
# 105          3        Medical            1.0            1640
#
#      EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
#display JobRole and MaritalStatus of female students
df[(df['Gender']=='Female')] [['JobRole','MaritalStatus']].head()
# Out:
#                   JobRole MaritalStatus
# 0         Sales Executive        Single
# 3    Sales Representative       Married
# 8   Laboratory Technician       Married
# 9         Sales Executive       Married
# 13  Laboratory Technician       Married

# %%
# Job Role with highest MonthlyIncome
df[df['MonthlyIncome'].max()==df['MonthlyIncome']] [['JobRole','MonthlyIncome']]
# Out:
#      JobRole  MonthlyIncome
# 184  Manager          19833

# %%
len(df[ 
(df['Department']=='Sales')  &
(df['EducationField']=='Medical') 
])
# Out:
# 27

# %%
len((df['Department']== 'Research & Developmet') )
# Out:
# 412

# %% [markdown]
# # Data Wrangling :-
#
#      Data wrangling is the process of removing errors and combining complex data sets to make them more
#     accessible and easier to analyze.
#     A data wrangling process, also known as a data munging process, consists of reorganizing, transforming and mapping data
#     from one "raw" form into another in order to make it more usable and valuable for a variety of downstream uses including
#     analytics.
#
# The most commonly used examples of data wrangling are for:
#
# -Merging several data sources into one data-set for analysis\
# -Identifying gaps or empty cells in data and either filling or removing them\
# -Deleting irrelevant or unnecessary data \
# -Identifying severe outliers in data and either explaining the inconsistencies or deleting them to facilitate analysis   \
# -Businesses also use data wrangling tools \

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum () # to check if any column contain null value
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  3
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               7
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
print("Toatl Null values in Department:",df['Department'].isnull().sum())
# Out:
# Toatl Null values in Department: 3

# %%
print("Toatl Null values in EmployeeCount:",df['EmployeeCount'].isnull().sum())
# Out:
# Toatl Null values in EmployeeCount: 7

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # dealing with missing values/ null values:
# 1- drop the row using dropna()\
# 2- replace the null values using replace()

# %%
#we drop null or Nan vallues usind dropna()
# axis=0 for rows  axis =1 for columns ,inplace=True for making change in original dataframe
df.dropna(subset=['Department'],axis=0,inplace=True)
print("Toatl Null values in Department:",df['Department'].isnull().sum() )# to check if null values droped
# Out:
# Toatl Null values in Department: 0

# %%
avgemp=df['EmployeeCount'].mean()
avgemp
# Out:
# 1.0

# %%
#we replace null values with mean using replace()
df['EmployeeCount']=df['EmployeeCount'].replace(np.nan,avgemp)

print("Toatl Null values in EmployeeCount:",df['EmployeeCount'].isnull().sum())
# Out:
# Toatl Null values in EmployeeCount: 0

# %%
df.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
df['Department'].value_counts() #count the number of records for every combination of unique values for every column
# Out:
# Research & Development    260
# Sales                     124
# Human Resources            25
# Name: Department, dtype: int64

# %% [markdown]
# # Find the name of the Department with highest MonthlyIncome

# %%
df[(df['MonthlyIncome'].max()==df['MonthlyIncome'])] [['MonthlyIncome','Department']].reset_index()
# Out:
#    index  MonthlyIncome Department
# 0    184          19833      Sales

# %% [markdown]
# # Top 5 EducationField with highest MonthlyIncome

# %%
a1=df.nlargest(5,'MonthlyIncome')
a1
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 184   40  Travel_Rarely        611                   Sales                 7
# 273   48  Travel_Rarely       1224  Research & Development                10
# 96    47  Travel_Rarely       1176         Human Resources                26
# 343   55  Travel_Rarely        189         Human Resources                26
# 71    42  Travel_Rarely       1059  Research & Development                 9
#
#      Education   EducationField  EmployeeCount  EmployeeNumber  \
# 184          4          Medical            1.0            1740
# 273          3    Life Sciences            1.0            1867
# 96           4    Life Sciences            1.0            1625
# 343          4  Human Resources            1.0            1973
# 71           2            Other            1.0            1595
#
#      EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
a1[ ['EducationField','MonthlyIncome']]
# Out:
#       EducationField  MonthlyIncome
# 184          Medical          19833
# 273    Life Sciences          19665
# 96     Life Sciences          19658
# 343  Human Resources          19636
# 71             Other          19613

# %%
#or
a=df.sort_values(by='MonthlyIncome',ascending=False) [['MonthlyIncome','EducationField']].head()
a
# Out:
#      MonthlyIncome   EducationField
# 184          19833          Medical
# 273          19665    Life Sciences
# 96           19658    Life Sciences
# 343          19636  Human Resources
# 71           19613            Other

# %% [markdown]
# # Find Top 7  EducationField as per MonthlyIncome

# %%
#t7=df.nlargest(7,'MonthlyIncome')[['EducationField','MonthlyIncome']].head(7)
#t7

# %%
#or
top7=df.sort_values(by=['MonthlyIncome'],ascending=False) [['EducationField','MonthlyIncome']].head(7)
top7
# Out:
#       EducationField  MonthlyIncome
# 184          Medical          19833
# 273    Life Sciences          19665
# 96     Life Sciences          19658
# 343  Human Resources          19636
# 71             Other          19613
# 58         Marketing          19586
# 379    Life Sciences          19431

# %%
plt.figure(figsize=(7,2))
sns.barplot(x='MonthlyIncome',y='EducationField',data=top7)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='EducationField'>

# %% [markdown]
# # Find bottom 4  Department as per MonthlyIncome

# %%
bottom4=df.sort_values(by=['MonthlyIncome'],ascending=True) [['EducationField','MonthlyIncome']].head(4)
bottom4
#or

#bottom=df.sort_values(by=['MonthlyIncome'],ascending=False) [['EducationField','MonthlyIncome']].tail(4)
#bottom
# Out:
#        EducationField  MonthlyIncome
# 280           Medical           1081
# 307  Technical Degree           1091
# 344           Medical           1129
# 147     Life Sciences           1393

# %%
df.nsmallest(4,'MonthlyIncome') [['EducationField','MonthlyIncome']]
# Out:
#        EducationField  MonthlyIncome
# 280           Medical           1081
# 307  Technical Degree           1091
# 344           Medical           1129
# 147     Life Sciences           1393

# %%
plt.figure(figsize=(10,2))
sns.barplot(x='MonthlyIncome',y='EducationField',data=bottom4)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='EducationField'>

# %%
df.head(2)
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 2                 9          3        Medical            1.0            1494
# 3                13          2  Life Sciences            1.0            1495
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 2                        2  ...                        3             80
# 3                        4  ...                        3             80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 2                 0                  4                     2                2
# 3                 1                  1                     2                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# ...

# %%
dr=df.sort_values(by=['DailyRate']) [['BusinessTravel','DailyRate']].head(6)

# %%
dr.head()
# Out:
#         BusinessTravel  DailyRate
# 52       Travel_Rarely        104
# 379         Non-Travel        105
# 371      Travel_Rarely        116
# 293  Travel_Frequently        117
# 74       Travel_Rarely        118

# %%
plt.figure(figsize=(5,2))
sns.barplot(x='DailyRate',y='BusinessTravel',data=dr)
plt.show()

# %%
df.head(1)
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 2   24  Travel_Frequently        381  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 2                 9          3        Medical            1.0            1494
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 2                        2  ...                        3             80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 2                 0                  4                     2                2
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 2              0                   0                        0
#
#    YearsWithCurrManager
# 2                     0
#
# [1 rows x 34 columns]

# %% [markdown]
# # Display Department and EducationField of top 3  DailyRate

# %%
ded= df.nlargest(3,'DailyRate') [['DailyRate','Department','EducationField']]
ded
# Out:
#      DailyRate              Department EducationField
# 144       1495  Research & Development        Medical
# 364       1490  Research & Development        Medical
# 284       1480                   Sales  Life Sciences

# %%
plt.figure(figsize=(5,3))

sns.barplot(x='DailyRate',y='Department',data=ded,hue='EducationField')
plt.legend(loc='upper right', bbox_to_anchor=(1.4, 1), title='TWYRating')
plt.show()

# %%
ded= df.nlargest(3,'DailyRate') [['DailyRate','Department','EducationField']].set_index('Department')
ded
# Out:
#                         DailyRate EducationField
# Department
# Research & Development       1495        Medical
# Research & Development       1490        Medical
# Sales                        1480  Life Sciences

# %%
plt.figure(figsize=(4,2))

sns.barplot(data=ded,y='DailyRate',x=ded.index,hue='EducationField')
plt.legend(loc='upper right', bbox_to_anchor=(1, 1), title='TWYRating')
plt.show()

# %% [markdown]
# # Data Normalization :
#     consists of transforming complex numeric columns to a standard scale.
#     Method of data normalization:
#         1.simple feature scaling : Xnew=Xold/Xmax (range between o to 1)
#         2. min- max scaling :   xnew = Xold-Xmin/ Xmax-Xmin (range between o to 1)
#         3.z-score scaling :     Xnew=Xold-mean/std .......... std=Standard deviation (range between -1 to 1 or -3 to 3)

# %%
df.head(2)
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 2                 9          3        Medical            1.0            1494
# 3                13          2  Life Sciences            1.0            1495
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 2                        2  ...                        3             80
# 3                        4  ...                        3             80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 2                 0                  4                     2                2
# 3                 1                  1                     2                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# ...

# %%
df['DailyRateScale']=df['DailyRate']/df['DailyRate'].max()  #simple feature Scaling 
df[['DailyRate','DailyRateScale']].head()
# Out:
#    DailyRate  DailyRateScale
# 2        381        0.254849
# 3        830        0.555184
# 4       1193        0.797993
# 5       1246        0.833445
# 6        330        0.220736

# %%
df['DailyRateScale2']=(df['DailyRate']-df['DailyRate'].min())/(df['DailyRate'].max()-df['DailyRate'].min()) #min-max scaling
df[['DailyRate','DailyRateScale2']].head(3)
# Out:
#    DailyRate  DailyRateScale2
# 2        381         0.199137
# 3        830         0.521927
# 4       1193         0.782890

# %%
#z-score scaling
df['DailyRateScale3']=(df['DailyRate'] - df['DailyRate'].mean()) / df['DailyRate'].std()
df[['DailyRate','DailyRateScale3']].head()
# Out:
#    DailyRate  DailyRateScale3
# 2        381        -1.032109
# 3        830         0.114463
# 4       1193         1.041424
# 5       1246         1.176766
# 6        330        -1.162343

# %% [markdown]
# # Drop Column
#   ; we use drop (axis=1)

# %%
df.drop(['DailyRateScale','DailyRateScale2','DailyRateScale3'] , axis=1, inplace=True)
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Binning :
#     Process of converting Numerical data into categorical bins
#     Ex. Salary into [low , high, medium ] bins
# for binning we use linspace() of numpy :\
# syntax : numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)
#
# cut() to segment and sort the data values into bins .

# %%
x = min(df['DistanceFromHome'])
y = max(df['DistanceFromHome'])
print(x)
print(y)
# Out:
# 1
# 29

# %%
bins = np.linspace(x,y,4)
group_name = ['Short','Medium','Long']
df['DistanceFromHomeBins'] = pd.cut(df['DistanceFromHome'], bins, labels=group_name,include_lowest=True)
bins
# Out:
# array([ 1.        , 10.33333333, 19.66666667, 29.        ])

# %%
df[['DistanceFromHome','DistanceFromHomeBins']].head(5)
# Out:
#    DistanceFromHome DistanceFromHomeBins
# 2                 9                Short
# 3                13               Medium
# 4                 2                Short
# 5                19               Medium
# 6                 1                Short

# %%
df['DistanceFromHomeBins'].value_counts()
# Out:
# Short     273
# Medium     68
# Long       68
# Name: DistanceFromHomeBins, dtype: int64

# %%
plt.figure(figsize=(4,2))
sns.countplot(df['DistanceFromHomeBins'])
# Out:
# <AxesSubplot:xlabel='DistanceFromHomeBins', ylabel='count'>

# %% [markdown]
#  # Turning Categorical values into  indicator variables.
#
# we use get_dummies(): to convert categorical ,variable into dummy variables(i.e into 0 or 1)

# %%
df.head(3)
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
# 4   44  Travel_Frequently       1193  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 2                 9          3        Medical            1.0            1494
# 3                13          2  Life Sciences            1.0            1495
# 4                 2          1        Medical            1.0            1496
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 2                        2  ...            80                 0
# 3                        4  ...            80                 1
# 4                        2  ...            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        294
# Travel_Frequently     72
# Non-Travel            43
# Name: BusinessTravel, dtype: int64

# %%
a=pd.get_dummies(df['BusinessTravel'])
a
# Out:
#      Non-Travel  Travel_Frequently  Travel_Rarely
# 2             0                  1              0
# 3             1                  0              0
# 4             0                  1              0
# 5             0                  0              1
# 6             0                  0              1
# ..          ...                ...            ...
# 407           0                  1              0
# 408           0                  0              1
# 409           0                  0              1
# 410           0                  1              0
# 411           0                  0              1
#
# [409 rows x 3 columns]

# %%
a.value_counts()
# Out:
# Non-Travel  Travel_Frequently  Travel_Rarely
# 0           0                  1                294
#             1                  0                 72
# 1           0                  0                 43
# dtype: int64

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
sns.countplot(df['DistanceFromHomeBins'])

plt.subplot(1,2,2)
plt.hist(df['DistanceFromHomeBins'])
plt.show()

# %% [markdown]
# # Exploratory Data Analysis:
#  To uncover relationship between variables
# The describe() function applies basic statistical computations on the dataset like extreme values, count of data points standard deviation, etc. Any missing value or NaN value is automatically skipped. describe() function gives a good picture of the distribution of data.
#
#
#  we can use boxplot and scatter plot to find outliers
#
#  Boxplot:A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.
#
#
#   Scatter plot:Scatter plots are used to observe relationship between variables and uses dots to represent the relationship between them.

# %%
df.describe(include='all')
# Out:
#                Age BusinessTravel    DailyRate              Department  \
# count   409.000000            409   409.000000                     409
# unique         NaN              3          NaN                       3
# top            NaN  Travel_Rarely          NaN  Research & Development
# freq           NaN            294          NaN                     260
# mean     36.569682            NaN   785.176039                     NaN
# std       8.402886            NaN   391.602081                     NaN
# min      18.000000            NaN   104.000000                     NaN
# 25%      31.000000            NaN   464.000000                     NaN
# 50%      36.000000            NaN   741.000000                     NaN
# 75%      42.000000            NaN  1153.000000                     NaN
# max      60.000000            NaN  1495.000000                     NaN
#
#         DistanceFromHome   Education EducationField  EmployeeCount  \
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010105          0.061159   0.298301
# DailyRate                 0.010105   1.000000         -0.084837   0.051209
# DistanceFromHome          0.061159  -0.084837          1.000000   0.046164
# Education                 0.298301   0.051209          0.046164   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber            0.015102  -0.005690          0.000792  -0.043409
# EnvironmentSatisfaction  -0.045295   0.008584         -0.000480  -0.086979
# HourlyRate                0.077078  -0.014247         -0.009978  -0.006570
# JobInvolvement           -0.012682   0.012441         -0.088111   0.071477
# JobLevel                  0.519222  -0.002337          0.094952   0.126550
# JobSatisfaction           0.036720   0.038692         -0.015715  -0.037122
# ...

# %%
df[['EmployeeNumber','Department']].head()
# Out:
#    EmployeeNumber              Department
# 2            1494  Research & Development
# 3            1495                   Sales
# 4            1496  Research & Development
# 5            1497                   Sales
# 6            1499         Human Resources

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x= 'Department',y='EmployeeNumber' ,data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='EmployeeNumber'>

# %%
df.head(3)
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
# 4   44  Travel_Frequently       1193  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 2                 9          3        Medical            1.0            1494
# 3                13          2  Life Sciences            1.0            1495
# 4                 2          1        Medical            1.0            1496
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 2                        2  ...            80                 0
# 3                        4  ...            80                 1
# 4                        2  ...            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
df.corr() # used to find the pairwise correlation of all columns in the Pandas Dataframe in Python.
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010105          0.061159   0.298301
# DailyRate                 0.010105   1.000000         -0.084837   0.051209
# DistanceFromHome          0.061159  -0.084837          1.000000   0.046164
# Education                 0.298301   0.051209          0.046164   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber            0.015102  -0.005690          0.000792  -0.043409
# EnvironmentSatisfaction  -0.045295   0.008584         -0.000480  -0.086979
# HourlyRate                0.077078  -0.014247         -0.009978  -0.006570
# JobInvolvement           -0.012682   0.012441         -0.088111   0.071477
# JobLevel                  0.519222  -0.002337          0.094952   0.126550
# JobSatisfaction           0.036720   0.038692         -0.015715  -0.037122
# ...

# %%
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
sns.scatterplot(x=df['Age'],y=df['TotalWorkingYears'],data=df)

plt.subplot(1,2,2)
sns.regplot(x=df['Age'],y=df['TotalWorkingYears'],data=df)
plt.tight_layout()

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
# 4   44  Travel_Frequently       1193  Research & Development
# 5   29      Travel_Rarely       1246                   Sales
# 6   30      Travel_Rarely        330         Human Resources
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 2                 9          3        Medical            1.0            1494
# 3                13          2  Life Sciences            1.0            1495
# 4                 2          1        Medical            1.0            1496
# 5                19          3  Life Sciences            1.0            1497
# 6                 1          3  Life Sciences            1.0            1499
#
#    EnvironmentSatisfaction  ... TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %% [markdown]
# # GropuBy : groupby()
#  It is a power function which allows you to split your data into seperate group to peform computation for better analysis.
#
# Pandas groupby is used for grouping the data according to the categories and apply a function to the categories. It also helps to aggregate data efficiently.

# %%
df_test = df[['Department','EducationField','EmployeeNumber']]
df_test.head()
# Out:
#                Department EducationField  EmployeeNumber
# 2  Research & Development        Medical            1494
# 3                   Sales  Life Sciences            1495
# 4  Research & Development        Medical            1496
# 5                   Sales  Life Sciences            1497
# 6         Human Resources  Life Sciences            1499

# %%
df_grpby = df_test.groupby(['Department','EducationField'])['EmployeeNumber'].mean().reset_index()
df_grpby
# Out:
#                 Department    EducationField  EmployeeNumber
# 0          Human Resources   Human Resources     1806.083333
# 1          Human Resources     Life Sciences     1746.714286
# 2          Human Resources           Medical     1744.750000
# 3          Human Resources             Other     1883.000000
# 4   Research & Development     Life Sciences     1773.131579
# 5   Research & Development           Medical     1769.653465
# 6   Research & Development             Other     1770.529412
# 7   Research & Development  Technical Degree     1750.285714
# 8                    Sales     Life Sciences     1760.729167
# 9                    Sales         Marketing     1863.324324
# 10                   Sales           Medical     1798.000000
# 11                   Sales             Other     1839.500000
# 12                   Sales  Technical Degree     1735.875000

# %% [markdown]
# # pivot_table():
# Create a spreadsheet-style pivot table as a DataFrame.
#
# pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False,
#                    dropna=True, margins_name='All', observed=False, sort=True)

# %%
df_pivot=df_grpby.pivot(index='Department',columns='EducationField')
df_pivot
# Out:
#                         EmployeeNumber                             \
# EducationField         Human Resources Life Sciences    Marketing
# Department
# Human Resources            1806.083333   1746.714286          NaN
# Research & Development             NaN   1773.131579          NaN
# Sales                              NaN   1760.729167  1863.324324
#
#
# EducationField              Medical        Other Technical Degree
# Department
# Human Resources         1744.750000  1883.000000              NaN
# Research & Development  1769.653465  1770.529412      1750.285714
# Sales                   1798.000000  1839.500000      1735.875000

# %%
df.pivot_table (index='Department',values='EmployeeNumber',columns="EducationField",aggfunc=sum)
# Out:
# EducationField          Human Resources  Life Sciences  Marketing   Medical  \
# Department
# Human Resources                 21673.0        12227.0        NaN    6979.0
# Research & Development              NaN       202137.0        NaN  178735.0
# Sales                               NaN        84515.0    68943.0   48546.0
#
# EducationField            Other  Technical Degree
# Department
# Human Resources          3766.0               NaN
# Research & Development  30099.0           49008.0
# Sales                    7358.0           13887.0

# %%
df.groupby('Department') [['Age','EmployeeNumber']].mean()
# Out:
#                               Age  EmployeeNumber
# Department
# Human Resources         35.360000     1785.800000
# Research & Development  36.815385     1769.150000
# Sales                   36.298387     1800.395161

# %% [markdown]
# #which education field have highest MonthlyIncome

# %%
df[(df['MonthlyIncome'].max()==df['MonthlyIncome'])]
# Out:
#      Age BusinessTravel  DailyRate Department  DistanceFromHome  Education  \
# 184   40  Travel_Rarely        611      Sales                 7          4
#
#     EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 184        Medical            1.0            1740                        2
#
#      ... TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 184  ...                21                      3                2
#
#      YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 184              21                  8                       12
#
#     YearsWithCurrManager  DistanceFromHomeBins  TotalWorkingYearRATING  \
# 184                    8                 Short                  Medium
#
#      TWYRating
# 184     Medium
#
# [1 rows x 37 columns]

# %%
df[(df['MonthlyIncome'].max()==df['MonthlyIncome'])]  ['EducationField']
# Out:
# 184    Medical
# Name: EducationField, dtype: object

# %% [markdown]
# Average MonthlyIncome  of male

# %%
df.groupby('Gender') ['MonthlyIncome'].mean()
# Out:
# Gender
# Female    6505.824324
# Male      6032.961686
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby('Gender') ['MonthlyIncome'].mean().sort_values(ascending=True).head(1)
# Out:
# Gender
# Male    6032.961686
# Name: MonthlyIncome, dtype: float64

# %%
df.TotalWorkingYears.max()
# Out:
# 37

# %%
df['TotalWorkingYears'].min()
# Out:
# 0

# %% [markdown]
# # Classify BusinessTravel based on TotalWorkingYears(low ,medium,high)

# %%
x=min(df['TotalWorkingYears'])
y=max(df['TotalWorkingYears'])
bins=np.linspace(x,y,4)
bins
# Out:
# array([ 0.        , 12.33333333, 24.66666667, 37.        ])

# %%
group_name=['low','Medium','high']
df['TotalWorkingYearRATING']=pd.cut(df['TotalWorkingYears'], bins, labels= group_name,include_lowest=True)
df[['TotalWorkingYears','TotalWorkingYearRATING']].head()
# Out:
#    TotalWorkingYears TotalWorkingYearRATING
# 2                  4                    low
# 3                  1                    low
# 4                 16                 Medium
# 5                 10                    low
# 6                  6                    low

# %%
len(df['TotalWorkingYearRATING']=='low')
# Out:
# 409

# %%
def year_function(a):
    if a> 25:
        return "High"
    if a> 15:
        return "Medium"
    else:
        return "Low"
df['TWYRating']=df['TotalWorkingYears'].apply(year_function)
df[['TWYRating','TotalWorkingYears']].head()
# Out:
#   TWYRating  TotalWorkingYears
# 2       Low                  4
# 3       Low                  1
# 4    Medium                 16
# 5       Low                 10
# 6       Low                  6

# %%
len(df.TWYRating=='Low')
# Out:
# 409

# %% [markdown]
# # Total MonthlyIncome  of Sales department by EducationField

# %%
a=pd.pivot_table(df,index='Department',columns='EducationField',values='MonthlyIncome',aggfunc=sum)
a
# Out:
# EducationField          Human Resources  Life Sciences  Marketing   Medical  \
# Department
# Human Resources                 58440.0        49755.0        NaN   23534.0
# Research & Development              NaN       700075.0        NaN  618620.0
# Sales                               NaN       336155.0   271953.0  170739.0
#
# EducationField             Other  Technical Degree
# Department
# Human Resources           7062.0               NaN
# Research & Development  102364.0          127207.0
# Sales                    17786.0           53775.0

# %%
newdf2=df[['Department','EducationField','MonthlyIncome']]
newdf2.groupby(['Department','EducationField'],as_index=False).sum() 
# including all the departments
# Out:
#                 Department    EducationField  MonthlyIncome
# 0          Human Resources   Human Resources          58440
# 1          Human Resources     Life Sciences          49755
# 2          Human Resources           Medical          23534
# 3          Human Resources             Other           7062
# 4   Research & Development     Life Sciences         700075
# 5   Research & Development           Medical         618620
# 6   Research & Development             Other         102364
# 7   Research & Development  Technical Degree         127207
# 8                    Sales     Life Sciences         336155
# 9                    Sales         Marketing         271953
# 10                   Sales           Medical         170739
# 11                   Sales             Other          17786
# 12                   Sales  Technical Degree          53775

# %%
df_sales = df[ df['Department']=='Sales' ]
len(df_sales) #124 rows where Department is Sales
# Out:
# 124

# %%
pd.pivot_table( df_sales  ,index='Department',columns='EducationField',values='MonthlyIncome',aggfunc=sum)
# Out:
# EducationField  Life Sciences  Marketing  Medical  Other  Technical Degree
# Department
# Sales                  336155     271953   170739  17786             53775

# %%
edu_field = df_sales.groupby('EducationField') ['MonthlyIncome'].sum().reset_index()
edu_field.head()
# Out:
#      EducationField  MonthlyIncome
# 0     Life Sciences         336155
# 1         Marketing         271953
# 2           Medical         170739
# 3             Other          17786
# 4  Technical Degree          53775

# %%
pd.pivot_table(df_sales,index='EducationField', columns='Department',values='MonthlyIncome',aggfunc='sum')
# Out:
# Department         Sales
# EducationField
# Life Sciences     336155
# Marketing         271953
# Medical           170739
# Other              17786
# Technical Degree   53775

# %%
pd.pivot_table(df_sales,index='Department', columns='EducationField',values='MonthlyIncome',aggfunc='count')
# Out:
# EducationField  Life Sciences  Marketing  Medical  Other  Technical Degree
# Department
# Sales                      48         37       27      4                 8

# %%
plt.figure(figsize=(7,3))
sns.barplot(x='EducationField', y='MonthlyIncome',data=edu_field)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize=(3,2))
sns.countplot(x='Gender',hue='TWYRating',data=df)

plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1.05), title='TWYRating')
plt.show()

# %%
df.Gender.value_counts()
# Out:
# Male      261
# Female    148
# Name: Gender, dtype: int64

# %% [markdown]
# # subplot() :you can draw multiple plots in one figure

# %%
plt.figure(figsize=(5,5))
plt.subplot(2, 1, 1) 
sns.countplot(x='Gender',hue='TWYRating',data=df)
plt.title("TWYRating")

plt.subplot(2, 1, 2)
sns.countplot(x='Gender',hue='DistanceFromHomeBins',data=df)
plt.legend(loc='upper right',title='Distance')
plt.title("DistanceFromHomeBins")

plt.tight_layout()  #automatically adjusts subplots 
plt.show()

# %%
plt.figure(figsize=(9,6))

plt.subplot(2,2,1) #the figure has 2 row, 2 columns, and this plot is the 1st plot.
plt.title('Department')
sns.countplot(x='Gender',hue='Department',data=df)

plt.subplot(2,2,2) #the figure has 2 row, 2 columns, and this plot is the 2nd plot
plt.title('EducationField')
sns.countplot(x='Gender',hue='EducationField',data=df)

plt.subplot(2,2,3)#the figure has 2 row, 2 columns, and this plot is the 3rd plot.
plt.title('BusinessTravel')
sns.countplot(x='Gender',hue='BusinessTravel',data=df)

plt.subplot(2,2,4)#the figure has 2 row, 2 columns, and this plot is the 4th plot.
plt.title('TWYRating')
sns.countplot(x='Gender',hue='TWYRating',data=df)

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'DistanceFromHomeBins',
#        'TotalWorkingYearRATING', 'TWYRating'],
#       dtype='object')
